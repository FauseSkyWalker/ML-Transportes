# %%
import pandas as pd
import chardet

# %%
# Caminho para seu arquivo CSV
caminho_csv = '/home/fause/ML-Transportes/DadosPRF/acidentes2025_todas_causas_tipos.csv'

# %%
# Carregar o CSV
with open(caminho_csv, 'rb') as f:
    result = chardet.detect(f.read(100000))  # Lê 100 KB
    print("Encoding detectado:", result['encoding'])
# Out:
# Encoding detectado: ISO-8859-1

# %%
df = pd.read_csv(caminho_csv, encoding='iso-8859-1', sep=';')

# %%
# Mostrar os nomes das colunas
print("Colunas:")
print(df.columns.tolist())
# Out:
# Colunas:
# ['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km', 'municipio', 'causa_principal', 'causa_acidente', 'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente', 'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca', 'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade', 'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos', 'latitude', 'longitude', 'regional', 'delegacia', 'uop']

# %%
# Mostrar o número de linhas e colunas
print(f"\nNúmero de linhas: {df.shape[0]}")
print(f"Número de colunas: {df.shape[1]}")
# Out:
# Número de linhas: 279907
# Número de colunas: 37

# %%
# Mostrar as primeiras 5 linhas (opcional)
print("\nPrimeiras linhas:")
print(df.head())
# Out:
# Primeiras linhas:
#          id      pesid data_inversa    dia_semana   horario  uf     br    km  \
# 0  652468.0  1467636.0   2025-01-01  quarta-feira  00:30:00  PE  101.0  89,5
# 1  652468.0  1467635.0   2025-01-01  quarta-feira  00:30:00  PE  101.0  89,5
# 2  652468.0  1467634.0   2025-01-01  quarta-feira  00:30:00  PE  101.0  89,5
# 3  652468.0  1467637.0   2025-01-01  quarta-feira  00:30:00  PE  101.0  89,5
# 4  652469.0  1467628.0   2025-01-01  quarta-feira  00:50:00  SC  101.0   120
#
#                  municipio causa_principal  ...           sexo  ilesos  \
# 0  JABOATAO DOS GUARARAPES             Sim  ...  Não Informado     0.0
# 1  JABOATAO DOS GUARARAPES             Sim  ...       Feminino     0.0
# 2  JABOATAO DOS GUARARAPES             Sim  ...      Masculino     0.0
# 3  JABOATAO DOS GUARARAPES             Sim  ...  Não Informado     0.0
# 4                   ITAJAI             Sim  ...       Feminino     0.0
#
# ...
