# %%
import pandas as pd
import chardet

# %%
# Caminho para seu arquivo CSV
caminho_csv = '/home/fause/ML-Transportes/DadosPRF/datatran2025PorOcorrencia.csv'

# %%
# Carregar o CSV
with open(caminho_csv, 'rb') as f:
    result = chardet.detect(f.read(100000))  # Lê 100 KB
    print("Encoding detectado:", result['encoding'])
# Out:
# Encoding detectado: ISO-8859-1

# %%
df = pd.read_csv(caminho_csv, encoding='iso-8859-1', sep=';')

# %%
# Mostrar os nomes das colunas
print("Colunas:")
print(df.columns.tolist())
# Out:
# Colunas:
# ['id', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br', 'km', 'municipio', 'causa_acidente', 'tipo_acidente', 'classificacao_acidente', 'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista', 'tracado_via', 'uso_solo', 'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos', 'ignorados', 'feridos', 'veiculos', 'latitude', 'longitude', 'regional', 'delegacia', 'uop']

# %%
# Mostrar o número de linhas e colunas
print(f"\nNúmero de linhas: {df.shape[0]}")
print(f"Número de colunas: {df.shape[1]}")
# Out:
# Número de linhas: 34705
# Número de colunas: 30

# %%
# Mostrar as primeiras 5 linhas (opcional)
print("\nPrimeiras linhas:")
print(df.head())
# Out:
# Primeiras linhas:
#          id data_inversa    dia_semana   horario  uf   br     km  \
# 0  652493.0   2025-01-01  quarta-feira  06:20:00  SP  116    225
# 1  652519.0   2025-01-01  quarta-feira  07:50:00  CE  116  546,2
# 2  652522.0   2025-01-01  quarta-feira  08:45:00  PR  369   88,2
# 3  652544.0   2025-01-01  quarta-feira  11:00:00  PR  116     74
# 4  652549.0   2025-01-01  quarta-feira  09:30:00  MG  251    471
#
#                municipio                            causa_acidente  \
# 0              GUARULHOS  Reação tardia ou ineficiente do condutor
# 1              PENAFORTE                          Pista esburacada
# 2      CORNELIO PROCOPIO  Reação tardia ou ineficiente do condutor
# 3  CAMPINA GRANDE DO SUL  Reação tardia ou ineficiente do condutor
# 4           FRANCISCO SA                   Velocidade Incompatível
#
#                tipo_acidente  ... feridos_graves ilesos ignorados feridos  \
# ...
