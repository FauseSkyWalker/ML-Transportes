# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
sns.set_theme()

# %%
# df = pd.read_csv(
#     r'C:\Fause\Programas\EngSoft\repos\ML-Transportes\PBIC\acidentes_pbic_somas.csv',
#     encoding='utf-8',
#     parse_dates=['data_inversa'],
#     dayfirst=True,
#     low_memory=False
# )
# print("Shape inicial:", df.shape)

df = pd.read_csv(
    r'C:\Fause\Programas\EngSoft\repos\ML-Transportes\PBIC\acidentes_pbic_2020_2025_limpo.csv',
    encoding='utf-8',
    parse_dates=['data_inversa'],
    dayfirst=True,
    low_memory=False
)
print("Shape inicial:", df.shape)

# %%
print(df.columns)

# %%
# Retorna um array com os valores únicos
print(df['uso_solo'].unique())

# %%
print("Sem KM:", df["km"].isna().sum())
print("Sem latitude:", df["latitude"].isna().sum())
print("Sem longitude:", df["longitude"].isna().sum())

# %%
features = [
    'hora',
    'mes',
    'dia_semana',
    'fase_dia',
    'uf',
    'condicao_metereologica',
    'tipo_pista',
    'tracado_via',
    'uso_solo',
    'tipo_acidente',
    'km',
    'ano_fabricacao_veiculo'
]

# %%
df.isnull().mean().sort_values(ascending=False) * 100
