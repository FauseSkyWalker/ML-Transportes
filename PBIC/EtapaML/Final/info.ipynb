# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
sns.set_theme()

# %%
df = pd.read_csv(
    r'C:\Fause\Programas\EngSoft\repos\ML-Transportes\PBIC\acidentes_pbic_somas.csv',
    encoding='utf-8',
    parse_dates=['data_inversa'],
    dayfirst=True,
    low_memory=False
)
print("Shape inicial:", df.shape)
# Out:
# Shape inicial: (1678326, 53)

# %%
print(df.columns)
# Out:
# Index(['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br',
#        'km', 'municipio', 'causa_principal', 'causa_acidente',
#        'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista',
#        'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca',
#        'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade',
#        'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos',
#        'latitude', 'longitude', 'regional', 'delegacia', 'uop', 'ano_arquivo',
#        'mes', 'dia_mes', 'hora', 'gravidade_numerica', 'total_vitimas',
#        'Marca_Principal', 'Modelo_Grupo', 'Nome_Modelo', 'Fabricante',
#        'Modelo', 'Sum_Mortos', 'Sum_Feridos_Graves', 'Sum_Feridos_Leves',
#        'Sum_Ilesos', 'Sum_Total_Vitimas'],
#       dtype='str')

# %%
# Retorna um array com os valores únicos
print(df['tracado_via'].unique())
# Out:
# [3.300e+01       nan 5.000e+01 1.600e+01 3.700e+01 4.700e+01 3.000e+01
#  5.800e+01 3.800e+01 2.700e+01 2.400e+01 2.900e+01 2.800e+01 5.200e+01
#  2.300e+01 5.300e+01 2.200e+01 4.200e+01 3.400e+01 1.900e+01 4.000e+01
#  3.200e+01 2.000e+01 3.100e+01 2.600e+01 2.100e+01 6.400e+01 5.400e+01
#  2.500e+01 4.300e+01 6.800e+01 5.700e+01 5.100e+01 6.100e+01 5.500e+01
#  3.600e+01 4.500e+01 5.900e+01 4.100e+01 7.000e+01 4.800e+01 6.000e+01
#  5.600e+01 4.400e+01 6.300e+01 3.500e+01 4.600e+01 3.900e+01 6.200e+01
#  6.700e+01 4.900e+01 7.100e+01 6.600e+01 8.200e+01 7.400e+01 7.700e+01
#  1.500e+01 7.300e+01 6.900e+01 1.700e+01 7.200e+01 6.500e+01 8.000e+01
#  7.800e+01 1.800e+01 8.400e+01 7.900e+01 7.600e+01 7.500e+01 8.300e+01
#  8.700e+01 8.100e+01 8.600e+01 1.400e+01 8.500e+01 8.900e+01 8.800e+01
#  9.100e+01 2.019e+03 9.000e+01 0.000e+00 1.100e+01 1.033e+03 1.200e+02
#  9.090e+02 1.200e+01 1.300e+01 9.470e+02 5.000e+00 1.020e+03 8.000e+00
#  1.000e+01 1.190e+02 9.000e+00 9.200e+01 6.000e+00 9.300e+01 2.200e+02
#  1.823e+03 1.920e+03 9.100e+02 9.400e+01 2.000e+00 1.210e+02 8.250e+02
#  9.480e+02 2.020e+03 8.090e+02 2.430e+02 1.000e+00 9.110e+02 2.021e+03
#  1.921e+03 1.220e+02 9.350e+02 1.022e+03 9.490e+02 1.000e+02 1.049e+03
#  7.000e+00 2.022e+03 9.120e+02 1.480e+02 1.922e+03 1.023e+03 1.250e+02
#  1.230e+02 1.420e+02 8.330e+02 1.240e+02 5.240e+02 9.130e+02 1.923e+03
#  9.700e+01 2.023e+03 1.505e+03 5.300e+02 8.120e+02 3.000e+00 2.024e+03
#  1.046e+03 9.140e+02]

# %%
print("Sem KM:", df["km"].isna().sum())
print("Sem latitude:", df["latitude"].isna().sum())
print("Sem longitude:", df["longitude"].isna().sum())
# Out:
# Sem KM: 4804
# Sem latitude: 0
# Sem longitude: 0

# %%
features = [
    'hora',
    'mes',
    'dia_semana',
    'fase_dia',
    'uf',
    'condicao_metereologica',
    'tipo_pista',
    'tracado_via',
    'uso_solo',
    'tipo_acidente',
    'km',
    'ano_fabricacao_veiculo'
]

# %%
df.isnull().mean().sort_values(ascending=False) * 100
# Out:
# Sum_Feridos_Graves        14.830492
# Sum_Mortos                14.830492
# Sum_Feridos_Leves         14.830492
# Sum_Ilesos                14.830492
# Sum_Total_Vitimas         14.830492
# idade                      7.806469
# br                         0.286238
# km                         0.286238
# Modelo_Grupo               0.110825
# uop                        0.110527
# delegacia                  0.041112
# regional                   0.007686
# classificacao_acidente     0.002800
# horario                    0.000000
# dia_semana                 0.000000
# data_inversa               0.000000
# uf                         0.000000
# causa_principal            0.000000
# causa_acidente             0.000000
# pesid                      0.000000
# id                         0.000000
# id_veiculo                 0.000000
# uso_solo                   0.000000
# tracado_via                0.000000
# tipo_pista                 0.000000
# condicao_metereologica     0.000000
# sentido_via                0.000000
# fase_dia                   0.000000
# tipo_acidente              0.000000
# municipio                  0.000000
# ordem_tipo_acidente        0.000000
# ilesos                     0.000000
# sexo                       0.000000
# tipo_envolvido             0.000000
# tipo_veiculo               0.000000
# ano_fabricacao_veiculo     0.000000
# marca                      0.000000
# longitude                  0.000000
# feridos_graves             0.000000
# mortos                     0.000000
# latitude                   0.000000
# feridos_leves              0.000000
# estado_fisico              0.000000
# dia_mes                    0.000000
# ano_arquivo                0.000000
# Marca_Principal            0.000000
# total_vitimas              0.000000
# gravidade_numerica         0.000000
# hora                       0.000000
# mes                        0.000000
# Modelo                     0.000000
# Nome_Modelo                0.000000
# Fabricante                 0.000000
# dtype: float64
