# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv(
    "/home/fause/ML-Transportes/PBIC/Etapa3/acidentes_pbic_2020_2025_Final.csv",
    encoding="utf-8",
    parse_dates=["data_inversa"],
    dayfirst=True,
    low_memory=False
)

print(df.shape)
df.head()
# Out:
# (1678326, 48)
#          id     pesid data_inversa    dia_semana   horario  uf     br     km  \
# 0  260031.0  578475.0   2020-01-01  quarta-feira  01:00:00  TO  153.0  678,1
# 1  260031.0  578475.0   2020-01-01  quarta-feira  01:00:00  TO  153.0  678,1
# 2  260036.0  582005.0   2020-01-01  quarta-feira  01:00:00  RJ  116.0    178
# 3  260036.0  582005.0   2020-01-01  quarta-feira  01:00:00  RJ  116.0    178
# 4  260037.0  578473.0   2020-01-01  quarta-feira  01:52:00  SC  101.0  206,9
#
#      municipio causa_principal  ... mes  dia_mes hora gravidade_numerica  \
# 0       GURUPI             Sim  ...   1        1    1                  2
# 1       GURUPI             Sim  ...   1        1    1                  2
# 2  NOVA IGUACU             Não  ...   1        1    1                  0
# 3  NOVA IGUACU             Sim  ...   1        1    1                  0
# 4     SAO JOSE             Sim  ...   1        1    1                  0
#
#   total_vitimas Marca_Principal                               Modelo_Grupo  \
# 0           1.0            FIAT    SIENA ATTRACTIV 1.4/SIENA ATTRACTIV 1.4
# 1           1.0            FIAT    SIENA ATTRACTIV 1.4/SIENA ATTRACTIV 1.4
# 2           1.0   Não Informado                Não Informado/Não Informado
# 3           1.0   Não Informado                Não Informado/Não Informado
# 4           1.0              VW  NOVA SAVEIRO RB MBVS/NOVA SAVEIRO RB MBVS
#
#   Nome_Modelo     Fabricante Modelo
# 0       SIENA           FIAT  SIENA
# 1       SIENA           FIAT  SIENA
# 2          NO  Não Informado     NO
# 3          NO  Não Informado     NO
# 4        NOVA     VOLKSWAGEN   NOVA
#
# [5 rows x 48 columns]

# %%
df = df.dropna(subset=["gravidade_numerica"])

df["grave"] = (df["gravidade_numerica"] >= 2).astype(int)

# %%
df['data_inversa'] = pd.to_datetime(df['data_inversa'], format='%d/%m/%Y', errors='coerce')


df["hora"] = df["horario"].str.slice(0,2).astype(int)
df["periodo"] = pd.cut(
    df["hora"],
    bins=[0,6,12,18,24],
    labels=["madrugada", "manhã", "tarde", "noite"],
    include_lowest=True
)

df['dia_semana'] = df['data_inversa'].dt.weekday
df['fim_semana'] = df['dia_semana'].isin([5,6]).map({True:"fim_semana", False:"dia_util"})

# %%
cols = [
    "grave",
    "tipo_veiculo",
    "tipo_pista",
    "fase_dia",
    "condicao_metereologica",
    "sentido_via",
    "periodo",
    "fim_semana",
    "classificacao_acidente",
]
df_rules = df[cols].copy()

df_rules.head()
# Out:
#    grave tipo_veiculo tipo_pista     fase_dia condicao_metereologica  \
# 0      1    Automóvel    Simples  Plena Noite                Nublado
# 1      1    Automóvel    Simples  Plena Noite                Nublado
# 2      0       Outros      Dupla  Plena Noite              Céu Claro
# 3      0       Outros      Dupla  Plena Noite              Céu Claro
# 4      0  Caminhonete    Simples  Plena Noite                Nublado
#
#    sentido_via    periodo fim_semana classificacao_acidente
# 0    Crescente  madrugada   dia_util    Com Vítimas Feridas
# 1    Crescente  madrugada   dia_util    Com Vítimas Feridas
# 2  Decrescente  madrugada   dia_util     Com Vítimas Fatais
# 3  Decrescente  madrugada   dia_util     Com Vítimas Fatais
# 4    Crescente  madrugada   dia_util    Com Vítimas Feridas

# %%
transactions = df_rules.apply(lambda x: [f"{col}={x[col]}" for col in df_rules.columns], axis=1)
transactions = transactions.tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_tf = pd.DataFrame(te_ary, columns=te.columns_)

df_tf.head()
# Out:
#    classificacao_acidente=Com Vítimas Fatais  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    classificacao_acidente=Com Vítimas Feridas  \
# 0                                        True
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
#
#    classificacao_acidente=Sem Vítimas  classificacao_acidente=nan  \
# 0                               False                       False
# 1                               False                       False
# 2                               False                       False
# 3                               False                       False
# 4                               False                       False
#
#    condicao_metereologica=Chuva  condicao_metereologica=Céu Claro  \
# 0                         False                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
#
#    condicao_metereologica=Garoa/Chuvisco  condicao_metereologica=Granizo  \
# 0                                  False                           False
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                           False
#
#    condicao_metereologica=Ignorado  condicao_metereologica=Neve  ...  \
# 0                            False                        False  ...
# 1                            False                        False  ...
# 2                            False                        False  ...
# 3                            False                        False  ...
# 4                            False                        False  ...
#
#    tipo_veiculo=Outros  tipo_veiculo=Quadriciclo  tipo_veiculo=Reboque  \
# 0                False                     False                 False
# 1                False                     False                 False
# 2                False                     False                 False
# 3                False                     False                 False
# 4                False                     False                 False
#
#    tipo_veiculo=Semireboque  tipo_veiculo=Trator de esteira  \
# 0                     False                           False
# 1                     False                           False
# 2                     False                           False
# 3                     False                           False
# 4                     False                           False
#
#    tipo_veiculo=Trator de rodas  tipo_veiculo=Trator misto  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    tipo_veiculo=Triciclo  tipo_veiculo=Utilitário  tipo_veiculo=Ônibus
# 0                  False                    False                False
# 1                  False                    False                False
# 2                  False                    False                False
# 3                  False                    False                False
# 4                  False                    False                False
#
# [5 rows x 55 columns]

# %%
# Verificar tamanho dos dados
print(f"Número de transações: {len(df_tf)}")
print(f"Número de itens únicos: {len(df_tf.columns)}")
print(f"Tamanho estimado em memória: {df_tf.memory_usage(deep=True).sum() / 1024**3:.2f} GB")

# Se necessário, reduzir a amostra
if len(df_tf) > 100000:
    print("\n⚠️ Dataset muito grande! Reduzindo para 100.000 amostras...")
    df_tf_sample = df_tf.sample(n=100000, random_state=42)
else:
    df_tf_sample = df_tf

print(f"\nUsando {len(df_tf_sample)} transações para análise")
# Out:
# Número de transações: 1576318
# Número de itens únicos: 55
# Tamanho estimado em memória: 0.08 GB
#
# ⚠️ Dataset muito grande! Reduzindo para 100.000 amostras...
#
# Usando 100000 transações para análise

# %%
# Usar low_memory=True e aumentar min_support para reduzir uso de memória
freq_items = apriori(df_tf_sample, min_support=0.01, use_colnames=True, low_memory=True, verbose=1)
freq_items.sort_values("support", ascending=False).head(10)
# Out:
# Processing 20 combinations | Sampling itemset size 9876
#      support                                           itemsets
# 13   1.00000                              (fim_semana=dia_util)
# 242  0.82414                     (fim_semana=dia_util, grave=0)
# 14   0.82414                                          (grave=0)
# 1    0.75411       (classificacao_acidente=Com Vítimas Feridas)
# 64   0.75411  (fim_semana=dia_util, classificacao_acidente=C...
# 599  0.64173  (fim_semana=dia_util, classificacao_acidente=C...
# 65   0.64173  (classificacao_acidente=Com Vítimas Feridas, g...
# 4    0.61318                 (condicao_metereologica=Céu Claro)
# 126  0.61318  (condicao_metereologica=Céu Claro, fim_semana=...
# 224  0.55967          (fase_dia=Pleno dia, fim_semana=dia_util)

# %%
rules = association_rules(freq_items, metric="confidence", min_threshold=0.2)
rules = rules.sort_values("lift", ascending=False)
rules.head()
# Out:
#                                              antecedents  \
# 24155  (periodo=noite, classificacao_acidente=Com Vít...
# 24145  (fase_dia=Plena Noite, tipo_pista=Simples, gra...
# 63375  (fase_dia=Plena Noite, tipo_pista=Simples, fim...
# 63402  (periodo=noite, classificacao_acidente=Com Vít...
# 63398  (periodo=noite, fim_semana=dia_util, classific...
#
#                                              consequents  antecedent support  \
# 24155  (fase_dia=Plena Noite, tipo_pista=Simples, gra...             0.03209
# 24145  (periodo=noite, classificacao_acidente=Com Vít...             0.04579
# 63375  (periodo=noite, classificacao_acidente=Com Vít...             0.04579
# 63402  (fase_dia=Plena Noite, tipo_pista=Simples, fim...             0.03209
# 63398  (fase_dia=Plena Noite, tipo_pista=Simples, gra...             0.03209
#
#        consequent support  support  confidence      lift  representativity  \
# 24155             0.04579   0.0125    0.389529  8.506867               1.0
# 24145             0.03209   0.0125    0.272985  8.506867               1.0
# 63375             0.03209   0.0125    0.272985  8.506867               1.0
# 63402             0.04579   0.0125    0.389529  8.506867               1.0
# 63398             0.04579   0.0125    0.389529  8.506867               1.0
#
#        leverage  conviction  zhangs_metric  jaccard  certainty  kulczynski
# 24155  0.011031    1.563073       0.911705  0.19119   0.360235    0.331257
# 24145  0.011031    1.331349       0.924794  0.19119   0.248882    0.331257
# 63375  0.011031    1.331349       0.924794  0.19119   0.248882    0.331257
# 63402  0.011031    1.563073       0.911705  0.19119   0.360235    0.331257
# 63398  0.011031    1.563073       0.911705  0.19119   0.360235    0.331257

# %%
rules_graves = rules[rules["consequents"].astype(str).str.contains("grave=1")]
rules_graves = rules_graves.sort_values(["lift", "confidence"], ascending=False)

rules_graves.head(20)
# Out:
#                                               antecedents  \
# 24155   (periodo=noite, classificacao_acidente=Com Vít...
# 63402   (periodo=noite, classificacao_acidente=Com Vít...
# 63398   (periodo=noite, fim_semana=dia_util, classific...
# 24153   (fase_dia=Plena Noite, classificacao_acidente=...
# 63391   (fase_dia=Plena Noite, fim_semana=dia_util, cl...
# 63400   (fase_dia=Plena Noite, classificacao_acidente=...
# 125002  (fase_dia=Plena Noite, tipo_pista=Simples, tip...
# 93696   (fase_dia=Plena Noite, tipo_pista=Simples, tip...
# 124984  (fase_dia=Plena Noite, tipo_pista=Simples, tip...
# 63392   (fase_dia=Plena Noite, tipo_pista=Simples, cla...
# 24147   (fase_dia=Plena Noite, tipo_pista=Simples, cla...
# 63380   (fase_dia=Plena Noite, tipo_pista=Simples, fim...
# 63387   (periodo=noite, tipo_pista=Simples, fim_semana...
# 63399   (tipo_pista=Simples, periodo=noite, classifica...
# 24152   (tipo_pista=Simples, periodo=noite, classifica...
# 124966  (fase_dia=Plena Noite, fim_semana=dia_util, ti...
# 124987  (fase_dia=Plena Noite, tipo_pista=Simples, tip...
# 93684   (fase_dia=Plena Noite, tipo_pista=Simples, tip...
# 124995  (periodo=noite, tipo_pista=Simples, tipo_veicu...
# 125007  (tipo_pista=Simples, tipo_veiculo=Motocicleta,...
#
#                                               consequents  antecedent support  \
# 24155   (fase_dia=Plena Noite, tipo_pista=Simples, gra...             0.03209
# 63402   (fase_dia=Plena Noite, tipo_pista=Simples, fim...             0.03209
# 63398   (fase_dia=Plena Noite, tipo_pista=Simples, gra...             0.03209
# 24153        (grave=1, tipo_pista=Simples, periodo=noite)             0.05297
# 63391        (grave=1, tipo_pista=Simples, periodo=noite)             0.05297
# 63400   (grave=1, tipo_pista=Simples, periodo=noite, f...             0.05297
# 125002  (grave=1, periodo=noite, fim_semana=dia_util, ...             0.04356
# 93696   (grave=1, periodo=noite, condicao_metereologic...             0.04356
# 124984  (grave=1, periodo=noite, condicao_metereologic...             0.04356
# 63392       (grave=1, periodo=noite, fim_semana=dia_util)             0.03763
# 24147                            (grave=1, periodo=noite)             0.03763
# 63380                            (grave=1, periodo=noite)             0.03763
# 63387                     (fase_dia=Plena Noite, grave=1)             0.02327
# 63399   (fase_dia=Plena Noite, fim_semana=dia_util, gr...             0.02327
# 24152                     (fase_dia=Plena Noite, grave=1)             0.02327
# 124966                           (grave=1, periodo=noite)             0.03047
# 124987      (grave=1, periodo=noite, fim_semana=dia_util)             0.03047
# 93684                            (grave=1, periodo=noite)             0.03047
# 124995  (fase_dia=Plena Noite, grave=1, condicao_meter...             0.02878
# 125007  (fase_dia=Plena Noite, fim_semana=dia_util, gr...             0.02878
#
#         consequent support  support  confidence      lift  representativity  \
# 24155              0.04579  0.01250    0.389529  8.506867               1.0
# 63402              0.04579  0.01250    0.389529  8.506867               1.0
# 63398              0.04579  0.01250    0.389529  8.506867               1.0
# 24153              0.02885  0.01250    0.235983  8.179641               1.0
# 63391              0.02885  0.01250    0.235983  8.179641               1.0
# 63400              0.02885  0.01250    0.235983  8.179641               1.0
# 125002             0.02868  0.01005    0.230716  8.044500               1.0
# 93696              0.02868  0.01005    0.230716  8.044500               1.0
# 124984             0.02868  0.01005    0.230716  8.044500               1.0
# 63392              0.04279  0.01250    0.332182  7.763070               1.0
# 24147              0.04279  0.01250    0.332182  7.763070               1.0
# 63380              0.04279  0.01250    0.332182  7.763070               1.0
# 63387              0.06968  0.01250    0.537172  7.709132               1.0
# 63399              0.06968  0.01250    0.537172  7.709132               1.0
# 24152              0.06968  0.01250    0.537172  7.709132               1.0
# 124966             0.04279  0.01005    0.329833  7.708171               1.0
# 124987             0.04279  0.01005    0.329833  7.708171               1.0
# 93684              0.04279  0.01005    0.329833  7.708171               1.0
# 124995             0.04556  0.01005    0.349201  7.664636               1.0
# 125007             0.04556  0.01005    0.349201  7.664636               1.0
#
#         leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 24155   0.011031    1.563073       0.911705  0.191190   0.360235    0.331257
# 63402   0.011031    1.563073       0.911705  0.191190   0.360235    0.331257
# 63398   0.011031    1.563073       0.911705  0.191190   0.360235    0.331257
# 24153   0.010972    1.271110       0.926840  0.180323   0.213286    0.334629
# 63391   0.010972    1.271110       0.926840  0.180323   0.213286    0.334629
# 63400   0.010972    1.271110       0.926840  0.180323   0.213286    0.334629
# 125002  0.008801    1.262629       0.915574  0.161602   0.208002    0.290567
# 93696   0.008801    1.262629       0.915574  0.161602   0.208002    0.290567
# 124984  0.008801    1.262629       0.915574  0.161602   0.208002    0.290567
# 63392   0.010890    1.433339       0.905250  0.184040   0.302328    0.312153
# 24147   0.010890    1.433339       0.905250  0.184040   0.302328    0.312153
# 63380   0.010890    1.433339       0.905250  0.184040   0.302328    0.312153
# 63387   0.010879    2.010079       0.891018  0.155376   0.502507    0.358282
# 63399   0.010879    2.010079       0.891018  0.155376   0.502507    0.358282
# 24152   0.010879    2.010079       0.891018  0.155376   0.502507    0.358282
# 124966  0.008746    1.428315       0.897618  0.158994   0.299874    0.282350
# 124987  0.008746    1.428315       0.897618  0.158994   0.299874    0.282350
# 93684   0.008746    1.428315       0.897618  0.158994   0.299874    0.282350
# 124995  0.008739    1.466566       0.895297  0.156323   0.318135    0.284895
# 125007  0.008739    1.466566       0.895297  0.156323   0.318135    0.284895

# %%
def interpret_rules(r):
    for _, row in r.iterrows():
        print(f"\n📌 Regra:")
        print(f"SE {set(row['antecedents'])} ENTÃO {set(row['consequents'])}")
        print(f"→ Suporte: {row['support']:.4f}")
        print(f"→ Confiança: {row['confidence']:.4f}")
        print(f"→ Lift: {row['lift']:.4f} (>=1 indica risco acima da média)")
        
interpret_rules(rules_graves.head(10))
# Out:
# 📌 Regra:
# SE {'periodo=noite', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'grave=1'}
# → Suporte: 0.0125
# → Confiança: 0.3895
# → Lift: 8.5069 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'periodo=noite', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'fim_semana=dia_util', 'grave=1'}
# → Suporte: 0.0125
# → Confiança: 0.3895
# → Lift: 8.5069 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'periodo=noite', 'fim_semana=dia_util', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'grave=1'}
# → Suporte: 0.0125
# → Confiança: 0.3895
# → Lift: 8.5069 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'grave=1', 'tipo_pista=Simples', 'periodo=noite'}
# → Suporte: 0.0125
# → Confiança: 0.2360
# → Lift: 8.1796 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'fim_semana=dia_util', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'grave=1', 'tipo_pista=Simples', 'periodo=noite'}
# → Suporte: 0.0125
# → Confiança: 0.2360
# → Lift: 8.1796 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'grave=1', 'tipo_pista=Simples', 'periodo=noite', 'fim_semana=dia_util'}
# → Suporte: 0.0125
# → Confiança: 0.2360
# → Lift: 8.1796 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'tipo_veiculo=Motocicleta'} ENTÃO {'grave=1', 'periodo=noite', 'fim_semana=dia_util', 'condicao_metereologica=Céu Claro'}
# → Suporte: 0.0100
# → Confiança: 0.2307
# → Lift: 8.0445 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'tipo_veiculo=Motocicleta'} ENTÃO {'grave=1', 'periodo=noite', 'condicao_metereologica=Céu Claro'}
# → Suporte: 0.0100
# → Confiança: 0.2307
# → Lift: 8.0445 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'tipo_veiculo=Motocicleta', 'fim_semana=dia_util'} ENTÃO {'grave=1', 'periodo=noite', 'condicao_metereologica=Céu Claro'}
# → Suporte: 0.0100
# → Confiança: 0.2307
# → Lift: 8.0445 (>=1 indica risco acima da média)
#
# 📌 Regra:
# SE {'fase_dia=Plena Noite', 'tipo_pista=Simples', 'classificacao_acidente=Com Vítimas Fatais'} ENTÃO {'grave=1', 'periodo=noite', 'fim_semana=dia_util'}
# → Suporte: 0.0125
# → Confiança: 0.3322
# → Lift: 7.7631 (>=1 indica risco acima da média)
